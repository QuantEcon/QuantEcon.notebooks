# %% [markdown]
# # Introduction to DBnomics in Python

# %% [markdown]
# This tutorial explains how to obtain economic [time series](https://en.wikipedia.org/wiki/Time_series) from [DBnomics](https://db.nomics.world/), how to manipulate them and how to visualize them.
#
# We will use well-known Python packages to achieve our goal, like [Pandas](http://pandas.pydata.org/) to represent tabular data, and [Altair](https://altair-viz.github.io/) to create the charts.
#
# We will also use the [`dbnomics` Python package](https://git.nomics.world/dbnomics/dbnomics-python-client) to obtain data from the DBnomics Web API.
#
# First, let's import those libraries:

# %%
import pandas as pd
import altair as alt
alt.renderers.enable('notebook')
from altair import Chart, Scale, Y

from dbnomics import fetch_series, fetch_series_by_api_link

# import dbnomics
# dbnomics.__enable_development_mode()

# %% [markdown]
# Note: in this notebook we are going to follow the conventions of the Scientific Python community. In particular, the `df` shortcut for `DataFrame`.

# %% [markdown]
# ## Fetch one time series by its code

# %% [markdown]
# First, let's assume that we know which series we want to download. A series identifier (ID) is defined by three values, formatted like this: `provider_code/dataset_code/series_code`. We can use the `fetch_series` function, previously imported from the `dbnomics` Python package.
#
# For example, to fetch the time series `EA19.1.0.0.0.ZUTN` from the ["Unemployment rate" [ZUTN] dataset](https://db.nomics.world/AMECO/ZUTN) belonging to the [AMECO provider](https://db.nomics.world/AMECO):

# %%
df1 = fetch_series('AMECO/ZUTN/EA19.1.0.0.0.ZUTN')

# %% [markdown]
# The returned data is stored in the `df1` variable. Its type is a [Pandas](http://pandas.pydata.org/) [`DataFrame`](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe).
#
# Now let's display the first rows of this `DataFrame` by using the `head` method, each row representing an observation of the time series:

# %%
df1.head()
# Out:
#   @frequency    Country Frequency                               Unit  \
# 0     annual  Euro area  Annually  (Percentage of active population)
# 1     annual  Euro area  Annually  (Percentage of active population)
# 2     annual  Euro area  Annually  (Percentage of active population)
# 3     annual  Euro area  Annually  (Percentage of active population)
# 4     annual  Euro area  Annually  (Percentage of active population)
#
#   dataset_code                                       dataset_name freq   geo  \
# 0         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 1         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 2         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 3         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 4         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
#
#   original_period     period provider_code        series_code series_name  \
# 0            1960 1960-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 1            1961 1961-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 2            1962 1962-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 3            1963 1963-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 4            1964 1964-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
#
#                               unit value
# 0  percentage-of-active-population    NA
# 1  percentage-of-active-population    NA
# 2  percentage-of-active-population    NA
# 3  percentage-of-active-population    NA
# 4  percentage-of-active-population    NA

# %% [markdown]
# In such `DataFrame`, you will always find at least those columns:
# - provider_code
# - dataset_code
# - dataset_name
# - series_code
# - series_name
# - original_period (a `string`)
# - period (a `datetime.date` of the first day of `original_period`)
# - value
# - @frequency (harmonized frequency generated by DBnomics)
#
# The other columns depend on the provider and on the dataset. They always come in pairs (for the code and the name). In `df1`, you have:
# - `unit` (code) and `Unit` (name)
# - `geo` (code) and `Country` (name)
# - `freq` (code) and `Frequency` (name)

# %% [markdown]
# To plot the `DataFrame`, we need to remove the missing values (`NA`).
#
# Note: DBnomics defines a unified `NA` value for missing values.
#
# Let's define the following `clean_dataframe` helper function, using Pandas `query` method:

# %%
def clean_dataframe(df):
    return df.query("value != 'NA'")

# %% [markdown]
# Clean the previously downloaded `df1` `DataFrame`:

# %%
df1_clean = clean_dataframe(df1)
df1_clean.head()
# Out:
#    @frequency    Country Frequency                               Unit  \
# 38     annual  Euro area  Annually  (Percentage of active population)
# 39     annual  Euro area  Annually  (Percentage of active population)
# 40     annual  Euro area  Annually  (Percentage of active population)
# 41     annual  Euro area  Annually  (Percentage of active population)
# 42     annual  Euro area  Annually  (Percentage of active population)
#
#    dataset_code                                       dataset_name freq   geo  \
# 38         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 39         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 40         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 41         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 42         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
#
#    original_period     period provider_code        series_code series_name  \
# 38            1998 1998-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 39            1999 1999-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 40            2000 2000-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 41            2001 2001-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 42            2002 2002-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
#
#                                unit value
# 38  percentage-of-active-population  10.4
# 39  percentage-of-active-population   9.7
# 40  percentage-of-active-population   8.9
# 41  percentage-of-active-population   8.3
# 42  percentage-of-active-population   8.6

# %% [markdown]
# Here we use the [Altair](https://altair-viz.github.io/) library to render charts, but you can use any other one like matplotlib, bqplot, plotly, etc.

# %%
chart = Chart(df1_clean).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
)
chart
# Out:
# <div class="vega-embed" id="a8133cfb-9cb9-453c-92e3-652fa8cb6d17"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Fetch two time series by their codes

# %% [markdown]
# Again, let's assume that we know which series we want to download. We can reuse the `fetch_series` function, this time with two series codes.
#
# For example, to fetch the time series `EA19.1.0.0.0.ZUTN` and `DNK.1.0.0.0.ZUTN` from the ["Unemployment rate" [ZUTN] dataset](https://db.nomics.world/AMECO/ZUTN) belonging to the [AMECO provider](https://db.nomics.world/AMECO):

# %%
df2 = fetch_series([
    'AMECO/ZUTN/EA19.1.0.0.0.ZUTN',
    'AMECO/ZUTN/DNK.1.0.0.0.ZUTN',
])
df2.head()
# Out:
#   @frequency    Country Frequency                               Unit  \
# 0     annual  Euro area  Annually  (Percentage of active population)
# 1     annual  Euro area  Annually  (Percentage of active population)
# 2     annual  Euro area  Annually  (Percentage of active population)
# 3     annual  Euro area  Annually  (Percentage of active population)
# 4     annual  Euro area  Annually  (Percentage of active population)
#
#   dataset_code                                       dataset_name freq   geo  \
# 0         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 1         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 2         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 3         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
# 4         ZUTN  Unemployment rate: total :- Member States: def...    a  ea19
#
#   original_period     period provider_code        series_code series_name  \
# 0            1960 1960-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 1            1961 1961-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 2            1962 1962-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 3            1963 1963-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
# 4            1964 1964-01-01         AMECO  EA19.1.0.0.0.ZUTN   Euro area
#
#                               unit value
# 0  percentage-of-active-population    NA
# 1  percentage-of-active-population    NA
# 2  percentage-of-active-population    NA
# 3  percentage-of-active-population    NA
# 4  percentage-of-active-population    NA

# %%
df2_clean = clean_dataframe(df2).query("period >= '2000'")

# %%
chart = Chart(df2_clean).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# <div class="vega-embed" id="e7cd2e0c-c19b-4a83-8024-3232338a76ad"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Fetch series using a code mask

# %% [markdown]
# The code mask notation is a very concise way to select one or many time series at once. It is not compatible with all the providers (see [this list](https://git.nomics.world/dbnomics/dbnomics-api/blob/293603323b907ed3200580ab0ebe01ce60789972/dbnomics_api/application.cfg#L21)).
#
# Quick description: given 3 dimensions "frequency", "country" and "indicator", you can select:
# - one time series by giving its code: `"M.FR.PCPIEC_IX"`
# - many series by enumerating dimensions codes: `"M.FR+DE.PCPIEC_IX"` is equivalent to `["M.FR.PCPIEC_IX", "M.DE.PCPIEC_IX"]`
# - many series by skipping a dimension, repeating `"."` in the code mask: `"M..PCPIEC_IX"` is equivalent to `["M.country1.PCPIEC_IX", "M.country2.PCPIEC_IX", ..., "M.countryN.PCPIEC_IX"]`

# %%
code_mask_df = fetch_series("IMF", "CPI", code_mask="M.FR+DE.PCPIEC_IX+PCPIA_IX")
code_mask_df = clean_dataframe(code_mask_df).query("period >= '2000' and period < '2002'")
code_mask_df.head()
# Out:
#     @frequency FREQ Frequency INDICATOR              Indicator  \
# 540    monthly    M   Monthly  PCPIA_IX  Clothing and footwear
# 541    monthly    M   Monthly  PCPIA_IX  Clothing and footwear
# 542    monthly    M   Monthly  PCPIA_IX  Clothing and footwear
# 543    monthly    M   Monthly  PCPIA_IX  Clothing and footwear
# 544    monthly    M   Monthly  PCPIA_IX  Clothing and footwear
#
#     REFERENCE_PERIOD REF_AREA Reference Area dataset_code  \
# 540            2010A       DE        Germany          CPI
# 541            2010A       DE        Germany          CPI
# 542            2010A       DE        Germany          CPI
# 543            2010A       DE        Germany          CPI
# 544            2010A       DE        Germany          CPI
#
#                    dataset_name original_period     period provider_code  \
# 540  Consumer Price Index (CPI)         2000-01 2000-01-01           IMF
# 541  Consumer Price Index (CPI)         2000-02 2000-02-01           IMF
# 542  Consumer Price Index (CPI)         2000-03 2000-03-01           IMF
# 543  Consumer Price Index (CPI)         2000-04 2000-04-01           IMF
# 544  Consumer Price Index (CPI)         2000-05 2000-05-01           IMF
#
#        series_code                                series_name value
# 540  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear  98.4
# 541  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear  98.2
# 542  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear  98.4
# 543  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear  98.5
# 544  M.DE.PCPIA_IX  Monthly – Germany – Clothing and footwear  98.4

# %%
chart = Chart(code_mask_df).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# <div class="vega-embed" id="ea8a828d-47fd-4b8b-9923-ac72e5c2fbd3"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Fetch time series by their dimensions

# %% [markdown]
# Searching by dimension is a less concise way to select time series than using the code mask, but it's universal: some fetchers are not compatible with the code mask notation.
#
# The following example fetches many series from the ["Doing Business" [DB]](https://db.nomics.world/WB/DB) dataset of the [World Bank](https://db.nomics.world/WB) provider, selecting for time series about France, Italy and Spain (`country` dimension), and the indicator "Procedures required to start a business - Women (number)" (`indicator` dimension):

# %%
df3 = fetch_series("WB", "DB", dimensions={
    "country": ["FR", "IT", "ES"],
    "indicator": ["IC.REG.PROC.WOMEN"],
})
df3.head()
# Out:
#   @frequency ATTRIBUTE country country_label dataset_code    dataset_name  \
# 0     annual                ES         Spain           DB  Doing Business
# 1     annual                ES         Spain           DB  Doing Business
# 2     annual                ES         Spain           DB  Doing Business
# 3     annual                ES         Spain           DB  Doing Business
# 4     annual                ES         Spain           DB  Doing Business
#
#            indicator                                    indicator_label  \
# 0  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 1  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 2  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 3  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 4  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
#
#   original_period     period provider_code           series_code  \
# 0            2003 2003-01-01            WB  IC.REG.PROC.WOMEN-ES
# 1            2004 2004-01-01            WB  IC.REG.PROC.WOMEN-ES
# 2            2005 2005-01-01            WB  IC.REG.PROC.WOMEN-ES
# 3            2006 2006-01-01            WB  IC.REG.PROC.WOMEN-ES
# 4            2007 2007-01-01            WB  IC.REG.PROC.WOMEN-ES
#
#                                          series_name  value
# 0  Procedures required to start a business - Wome...   10.0
# 1  Procedures required to start a business - Wome...   10.0
# 2  Procedures required to start a business - Wome...   10.0
# 3  Procedures required to start a business - Wome...   10.0
# 4  Procedures required to start a business - Wome...   10.0

# %% [markdown]
# To know the codes of the time series you got:

# %%
df3.series_code.unique().tolist()
# Out:
# ['IC.REG.PROC.WOMEN-ES', 'IC.REG.PROC.WOMEN-FR', 'IC.REG.PROC.WOMEN-IT']

# %%
df3_clean = clean_dataframe(df3)

# %%
chart = Chart(df3_clean).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# <div class="vega-embed" id="cf9812fa-fd78-41da-807c-89f77bbeabc1"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Fetch time series found on the web site

# %% [markdown]
# When you don't know the codes of the dimensions, provider, dataset or series, you can:
#
# - go to the page of a dataset on DBnomics website, for example [Doing Business](https://db.nomics.world/WB/DB),
# - select some dimensions by using the input widgets of the left column,
# - click on "Copy API link" in the menu of the "Download" button,
# - use the `fetch_series_by_api_link` function such as below.

# %%
df4 = fetch_series_by_api_link("https://api.db.nomics.world/series?dimensions=%7B%22country%22%3A%5B%22FR%22%2C%22IT%22%2C%22ES%22%5D%2C%22indicator%22%3A%5B%22IC.REG.PROC.WOMEN%22%5D%7D&provider_code=WB&dataset_code=DB")
df4.head()
# Out:
#   @frequency ATTRIBUTE country country_label dataset_code    dataset_name  \
# 0     annual                ES         Spain           DB  Doing Business
# 1     annual                ES         Spain           DB  Doing Business
# 2     annual                ES         Spain           DB  Doing Business
# 3     annual                ES         Spain           DB  Doing Business
# 4     annual                ES         Spain           DB  Doing Business
#
#            indicator                                    indicator_label  \
# 0  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 1  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 2  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 3  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
# 4  IC.REG.PROC.WOMEN  Procedures required to start a business - Wome...
#
#   original_period     period provider_code           series_code  \
# 0            2003 2003-01-01            WB  IC.REG.PROC.WOMEN-ES
# 1            2004 2004-01-01            WB  IC.REG.PROC.WOMEN-ES
# 2            2005 2005-01-01            WB  IC.REG.PROC.WOMEN-ES
# 3            2006 2006-01-01            WB  IC.REG.PROC.WOMEN-ES
# 4            2007 2007-01-01            WB  IC.REG.PROC.WOMEN-ES
#
#                                          series_name  value
# 0  Procedures required to start a business - Wome...   10.0
# 1  Procedures required to start a business - Wome...   10.0
# 2  Procedures required to start a business - Wome...   10.0
# 3  Procedures required to start a business - Wome...   10.0
# 4  Procedures required to start a business - Wome...   10.0

# %%
df4_clean = clean_dataframe(df4)

# %%
chart = Chart(df4_clean).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# <div class="vega-embed" id="18a93b8a-76a3-4628-acbf-5aa6a3e7b935"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# The chart is exactly the same than the previous one.

# %% [markdown]
# ## Fetch time series from the cart

# %% [markdown]
# On the [cart page](https://db.nomics.world/cart) of the DBnomics website, click on "Copy API link" and copy-paste it as an argument of the `fetch_series_by_api_link` function.
#
# Please note that when you update your cart, you have to copy this link again, because the link itself contains the IDs of the series in the cart.

# %%
cart_df = fetch_series_by_api_link("https://api.db.nomics.world/series?series_ids=BOE%2F8745%2FLPMB23A%2CBOE%2F8745%2FLPMB26A")
cart_df.head()
# Out:
#   @frequency     Freq dataset_code  \
# 0    monthly  Monthly         8745
# 1    monthly  Monthly         8745
# 2    monthly  Monthly         8745
# 3    monthly  Monthly         8745
# 4    monthly  Monthly         8745
#
#                                       dataset_name freq original_period  \
# 0  Monthly lending secured on dwellings: approvals    M         1999-01
# 1  Monthly lending secured on dwellings: approvals    M         1999-02
# 2  Monthly lending secured on dwellings: approvals    M         1999-03
# 3  Monthly lending secured on dwellings: approvals    M         1999-04
# 4  Monthly lending secured on dwellings: approvals    M         1999-05
#
#       period provider_code series_code  \
# 0 1999-01-01           BOE     LPMB23A
# 1 1999-02-01           BOE     LPMB23A
# 2 1999-03-01           BOE     LPMB23A
# 3 1999-04-01           BOE     LPMB23A
# 4 1999-05-01           BOE     LPMB23A
#
#                                          series_name   value
# 0  Monthly number of other specialist lenders' st...   942.0
# 1  Monthly number of other specialist lenders' st...  1569.0
# 2  Monthly number of other specialist lenders' st...  2097.0
# 3  Monthly number of other specialist lenders' st...  1849.0
# 4  Monthly number of other specialist lenders' st...  1873.0

# %% [markdown]
# ## Mix different frequencies on the same chart

# %%
multi_freq_df = clean_dataframe(fetch_series([
    "BEA/NIUnderlyingDetail-U001BC/S315-A",
    "BEA/NIUnderlyingDetail-U001BC/S315-Q",
    "BEA/NIUnderlyingDetail-U001BC/S315-M",
]))

# %%
chart = Chart(multi_freq_df).mark_line().encode(
    x='period',
    y=Y('value', scale=Scale(zero=False)),
    color='series_code',
)
chart
# Out:
# <div class="vega-embed" id="60971967-f0e3-47c3-be05-153165539ff3"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
